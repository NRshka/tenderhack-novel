# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="2"
DEVICE='cuda'

# %%
import pandas as pd
from ast import literal_eval
import re
import json
import numpy as np
from tqdm.notebook import tqdm
import implicit

# %%
from scipy.sparse import dok_matrix

# %%
data = pd.read_excel('/storage1/ryazantsev/tenderhack/DataSet_EKB_200000.xlsx')

# %%
def trim_invalid_items(x):
    if x is np.nan:
        return '[]'
    else:
        rindex = x.rfind('}')
        return x[:rindex+1]+']'

# %%
data['Другая продукция в контрактах']=data['Другая продукция в контрактах'].map(trim_invalid_items)

# %%
data_other_notna = data[data['Другая продукция в контрактах'].notna()]['Другая продукция в контрактах']

# %%
json.loads(data['Другая продукция в контрактах'].iloc[5])[-2:]
# Out:
# [{'OtherSkuId': 34591891,
#   'OtherSkuName': 'Ежедневник датированный 2021 год Attache Economy бумвинил A5 160 листов синий (147x206 мм)',
#   'Quantity': 10.0},
#  {'OtherSkuId': 35141961,
#   'OtherSkuName': 'Ежедневник датированный 2022 год Attache Leader искусственная кожа А5+ 336 листов красный (146х206 мм)',
#   'Quantity': 50.0}]

# %%
sku_numerator = {}

# %%
for i, index_ in enumerate(data['Идентификатор СТЕ'].values):
    sku_numerator[index_]=i

# %%
#prepare sparse matrix
cooccurence_matrix = dok_matrix((200000, 358000))
offset_index = 200000
invisible_sku = []

for sku_id_, ncontracts, other_sku in tqdm(data[['Идентификатор СТЕ', 'Кол-во заключенных контрактов', 'Другая продукция в контрактах']].itertuples(index=False)):
    other_sku = json.loads(other_sku)
    i = sku_numerator[sku_id_]
    for other_sku_ in other_sku:
        other_sku_id = other_sku_['OtherSkuId']
        if ncontracts>=1:
            quantity = other_sku_['Quantity']/ncontracts
            j = sku_numerator.get(other_sku_id)
            #if j and quantity>0.3:
            if j:
                #cooccurence_matrix[i,j] = quantity
                cooccurence_matrix[i,j] = min(quantity, 0.5)/0.5
            else:
                sku_numerator[other_sku_id] = offset_index
                invisible_sku.append(other_sku_)
                j = offset_index
                cooccurence_matrix[i,j] = min(quantity, 0.5)/0.5
                offset_index+=1
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
#Train model als
model = implicit.als.AlternatingLeastSquares(factors=25, regularization=0.1, iterations=20)
#alpha_val = 40
data_conf = (cooccurence_matrix).astype('double')
model.fit(data_conf)
# Out:
# WARNING:root:OpenBLAS detected. Its highly recommend to set the environment variable 'export OPENBLAS_NUM_THREADS=1' to disable its internal multithreading

# %%
def show_recommendations(index):
    recommended = model.similar_items(index,10)
    print(recommended)
    recommended_ind = list(map(lambda x: x[0], recommended))
    #return recommended_ind
    return data.iloc[recommended_ind]

# %%
show_recommendations(105)
# Out:
#        Идентификатор СТЕ                                   Наименование СТЕ  \
# 105             18077734  Блокнот Проф-пресс Городской стиль А5 80 листо...
# 64201           34025096  Тетрадь общая Проф-пресс Панорамы А5 48 листов...
# 9281             1232842  Планшет BANTEX 4210-01 A4 синий с верх.створко...
# 4349             1232757  Папка-регистратор BANTEX ECONOMY, 1446-09,б/ме...
# 91999           19427217  Лезвия для канцелярских ножей Berlingo, 18мм, ...
# 92664           33703671  Скрепки 28 мм, Berlingo, 100шт., золотистые, к...
# 7237             1249260  Корректирующая ручка 8мл KORES Preсiso, шарико...
# 22697            1227102  Коврик на стол Комус 47,5х66см прозрачный мато...
# 36581            1397416  Скрепочница магнитная Attache Selection вертик...
# 90216            1191381                      Berlingo Кнопки силовые 50 шт
#
#                                   Категория  \
# 105                                 Блокнот
# 64201             Тетрадь ученическая общая
# 9281                      Папки пластиковые
# 4349                        Папки картонные
# 91999                   Резаки канцелярские
# 92664                  Скрепки канцелярские
# 7237   Средства корректирующие канцелярские
# 22697                  Коврики канцелярские
# 36581               Скрепочницы пластиковые
# 90216                  Скрепки канцелярские
#
#                                                 Описание  \
# 105    Блокнот Проф-пресс Городской стиль А5 80 листо...
# 64201                                                NaN
# 9281                                                 NaN
# 4349                                                 NaN
# 91999                                                NaN
# 92664                                                NaN
# 7237                                                 NaN
# 22697                                                NaN
# 36581  Скрепочница магнитная Attache Selection вертик...
# 90216  Силовые кнопки "Berlingo" предназначены для со...
#
#                                       Характеристики СТЕ  \
# 105    [{"Name":"Вид деловой бумажной продукции","Id"...
# 64201  [{"Name":"Тип крепления","Id":-618845869,"Valu...
# 9281   [{"Name":"Формат","Id":291075708,"Value":"А4"}...
# 4349   [{"Name":"Материал внешнего покрытия","Id":368...
# 91999  [{"Name":"Запасное лезвие для канцелярского но...
# 92664  [{"Name":"Вид зажима для бумаг","Id":-63195841...
# 7237   [{"Name":"Страна происхождения","Id":299363107...
# 22697  [{"Name":"Страна производитель","Id":291010080...
# 36581  [{"Name":"Цвет","Id":325475640,"Value":"черный...
# 90216  [{"Name":"Тип","Id":284849745,"Value":"Канцеля...
#
#                                         Регионы поставки  \
# 105    [{"Name":"Белгородская"},{"Name":"Марий Эл"},{...
# 64201  [{"Name":"Белгородская"},{"Name":"Марий Эл"},{...
# 9281   [{"Name":"Белгородская"},{"Name":"Марий Эл"},{...
# 4349   [{"Name":"Белгородская"},{"Name":"Марий Эл"},{...
# 91999          [{"Name":"Москва"},{"Name":"Московская"}]
# 92664          [{"Name":"Москва"},{"Name":"Московская"}]
# 7237   [{"Name":"Белгородская"},{"Name":"Марий Эл"},{...
# 22697  [{"Name":"Белгородская"},{"Name":"Марий Эл"},{...
# 36581  [{"Name":"Белгородская"},{"Name":"Марий Эл"},{...
# 90216                                [{"Name":"Москва"}]
#
#        Кол-во заключенных контрактов  \
# 105                              6.0
# 64201                            3.0
# 9281                             5.0
# 4349                             8.0
# 91999                            6.0
# 92664                            8.0
# 7237                             7.0
# 22697                            9.0
# 36581                            4.0
# 90216                            7.0
#
#                                               Поставщики Страна происхождения  \
# 105    [{"SupplierId":1100019,"Name":"ООО \"ЦТО\"","I...               РОССИЯ
# 64201  [{"SupplierId":1100019,"Name":"ООО \"ЦТО\"","I...               РОССИЯ
# 9281   [{"SupplierId":1100019,"Name":"ООО \"ЦТО\"","I...               РОССИЯ
# 4349   [{"SupplierId":1100019,"Name":"ООО \"ЦТО\"","I...               РОССИЯ
# 91999  [{"SupplierId":1105608,"Name":"Общество с огра...                КИТАЙ
# 92664  [{"SupplierId":1259802,"Name":"ОБЩЕСТВО С ОГРА...                  NaN
# 7237   [{"SupplierId":1100019,"Name":"ООО \"ЦТО\"","I...   ЧЕШСКАЯ РЕСПУБЛИКА
# 22697  [{"SupplierId":1100019,"Name":"ООО \"ЦТО\"","I...                  NaN
# 36581  [{"SupplierId":1100019,"Name":"ООО \"ЦТО\"","I...                КИТАЙ
# 90216  [{"SupplierId":1101064,"Name":"ООО \"ОФИСНАЯ Т...                  NaN
#
#                            Другая продукция в контрактах  Просмотры  \
# 105    [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          8
# 64201  [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          3
# 9281   [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          3
# 4349   [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          8
# 91999  [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          7
# 92664  [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          8
# 7237   [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          2
# 22697  [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          6
# 36581  [{"OtherSkuId":1188993,"OtherSkuName":"Berling...          6
# 90216  [{"OtherSkuId":1188993,"OtherSkuName":"Berling...         16
#
#        Идентификатор КПГЗ              Код КПГЗ  \
# 105               66924.0           01.15.02.01
# 64201           1100146.0        01.15.02.06.02
# 9281           12114414.0        01.15.03.17.05
# 4349           12108439.0           01.15.03.16
# 91999          12114422.0        01.15.05.16.02
# 92664          12114410.0     01.15.05.04.06.01
# 7237           12118572.0     01.15.05.04.03.01
# 22697          12108457.0           01.15.05.13
# 36581          12118602.0  01.15.05.01.05.01.02
# 90216          12114410.0     01.15.05.04.06.01
#
#                                                   Модель  \
# 105                                      Городской стиль
# 64201                                            1159171
# 9281                                                 NaN
# 4349         BANTEX ECONOMY, 1446-09,б/мет.уг,70мм,красн
# 91999             Лезвия для канцелярских ножей Berlingo
# 92664                                              28 мм
# 7237                                                 NaN
# 22697                                                NaN
# 36581  Скрепочница магнитная вертикальная с черными с...
# 90216                                                NaN
#
#                                           Цена
# 105      [{"Cost":32.24000},{"Cost":40.91000}]
# 64201    [{"Cost":25.73000},{"Cost":27.10000}]
# 9281                      [{"Cost":296.00000}]
# 4349                      [{"Cost":283.00000}]
# 91999                                      NaN
# 92664                      [{"Cost":48.00000}]
# 7237                      [{"Cost":186.00000}]
# 22697  [{"Cost":502.20000},{"Cost":806.07000}]
# 36581                     [{"Cost":259.00000}]
# 90216                                      NaN

# %%
#Dumps weights als
np.save('weights/item_factors.npy',item_factors)
np.save('weights/item_norms.npy',item_norms)
